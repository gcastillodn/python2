# %% [markdown]
# ## Ejemplo 6: Sort
#
# ### 1. Objetivos:
#     - Aprender a usar `sort_values` para reordenar nuestros datos
#
# ### 2. Desarrollo:

# %%
import pandas as pd

# %%
df = pd.read_csv('new_york_times_bestsellers-dirty.csv', index_col=0)
df.head(3)
# Out:
#                                   amazon_product_url             author  \
# 0  http://www.amazon.com/The-Host-Novel-Stephenie...    Stephenie Meyer
# 1  http://www.amazon.com/Love-Youre-With-Emily-Gi...       Emily Giffin
# 2  http://www.amazon.com/The-Front-Garano-Patrici...  Patricia Cornwell
#
#                                          description      publisher  \
# 0  Descr: Aliens have taken control of the minds ...  Little, Brown
# 1  Descr: A woman's happy marriage is shaken when...   St. Martin's
# 2  Descr: A Massachusetts state investigator and ...         Putnam
#
#                       title                       oid  \
# 0                  THE HOST  5b4aa4ead3089013507db18c
# 1  LOVE THE ONE YOU'RE WITH  5b4aa4ead3089013507db18d
# 2                 THE FRONT  5b4aa4ead3089013507db18e
#
#   bestsellers_date.numberLong  published_date.numberLong rank.numberInt  \
# 0         2008-05-24 00:00:00              1212883200000              2
# 1         2008-05-24 00:00:00              1212883200000              3
# 2         2008-05-24 00:00:00              1212883200000              4
#
#    rank_last_week.numberInt  weeks_on_list.numberInt  price.numberDouble
# 0                         1                        3               25.99
# 1                         2                        2               24.95
# 2                         0                        1               22.95

# %% [markdown]
# Finalmente veamos como podemos ordenar los elementos de una DataFrame, por ejemplo, queremos ordenar nuestras entradas empezando por el libro de mayor precio hasta el libro de menor precio, así que se ordena en base a la columna `price.numberDouble` de manera descendente usando la siguiente forma de la función `sort_values()`:
#
# `dataframe.sort_values(-columna-, ascending=False)`

# %%
df.sort_values("price.numberDouble", ascending=False)
# Out:
#                                      amazon_product_url           author  \
# 2264  http://www.amazon.com/1Q84-Haruki-Murakami-ebo...  Haruki Murakami
# 2255  http://www.amazon.com/1Q84-Haruki-Murakami-ebo...  Haruki Murakami
# 2276  http://www.amazon.com/1Q84-Haruki-Murakami-ebo...  Haruki Murakami
# 2287  http://www.amazon.com/1Q84-Haruki-Murakami-ebo...  Haruki Murakami
# 2232  http://www.amazon.com/1Q84-Haruki-Murakami-ebo...  Haruki Murakami
# ...                                                 ...              ...
# 2205  http://www.amazon.com/1225-Christmas-Tree-Lane...  Debbie Macomber
# 237   http://www.amazon.com/Cedar-Cove-Christmas-Deb...  Debbie Macomber
# 1343  http://www.amazon.com/Blockade-Billy-Stephen-K...     Stephen King
# 1310  http://www.amazon.com/Blockade-Billy-Stephen-K...     Stephen King
# 1328  http://www.amazon.com/Blockade-Billy-Stephen-K...     Stephen King
#
#                                             description         publisher  \
# 2264  Descr: In 1980s Tokyo, a woman who punishes pe...             Knopf
# 2255  Descr: In 1980s Tokyo, a woman who punishes pe...             Knopf
# 2276  Descr: In 1980s Tokyo, a woman who punishes pe...             Knopf
# 2287  Descr: In 1980s Tokyo, a woman who punishes pe...             Knopf
# 2232  Descr: In 1980s Tokyo, a woman who punishes pe...             Knopf
# ...                                                 ...               ...
# 2205  Descr: Puppies and an ex-husband loom large in...              Mira
# 237   Descr: A pregnant woman shows up in Cedar Cove...              Mira
# 1343  Descr: A tale about the dark side of baseball,...          Scribner
# 1310  Descr: A tale about the dark side of baseball,...  Simon & Schuster
# 1328  Descr: A tale about the dark side of baseball,...          Scribner
#
#                          title                       oid  \
# 2264                      1Q84  5b4aa4ead3089013507dbff5
# 2255                      1Q84  5b4aa4ead3089013507dbfe2
# 2276                      1Q84  5b4aa4ead3089013507dc00b
# 2287                      1Q84  5b4aa4ead3089013507dc01e
# 2232                      1Q84  5b4aa4ead3089013507dbfb4
# ...                        ...                       ...
# 2205  1225 CHRISTMAS TREE LANE  5b4aa4ead3089013507dbf81
# 237     A CEDAR COVE CHRISTMAS  5b4aa4ead3089013507db30d
# 1343            BLOCKADE BILLY  5b4aa4ead3089013507db9f6
# 1310            BLOCKADE BILLY  5b4aa4ead3089013507db9c7
# 1328            BLOCKADE BILLY  5b4aa4ead3089013507db9df
#
#      bestsellers_date.numberLong  published_date.numberLong rank.numberInt  \
# 2264         2011-12-03 00:00:00              1324166400000             11
# 2255         2011-11-26 00:00:00              1323561600000             12
# 2276         2011-12-10 00:00:00              1324771200000             13
# 2287         2011-12-17 00:00:00              1325376000000             12
# 2232         2011-11-12 00:00:00              1322352000000              6
# ...                          ...                        ...            ...
# 2205         2011-10-22 00:00:00              1320537600000             15
# 237          2008-10-04 00:00:00              1224374400000              7
# 1343         2010-06-13 00:00:00              1277596800000             16
# 1310         2010-05-30 00:00:00              1276387200000              9
# 1328         2010-06-06 00:00:00              1276992000000             13
#
#       rank_last_week.numberInt  weeks_on_list.numberInt  price.numberDouble
# 2264                        12                        6               30.50
# 2255                        10                        5               30.50
# 2276                        11                        7               30.50
# 2287                        13                        8               30.50
# 2232                         6                        3               30.50
# ...                        ...                      ...                 ...
# 2205                        10                        4               16.95
# 237                          0                        1               16.95
# 1343                        13                        3               14.99
# 1310                         0                        1               14.99
# 1328                         9                        2               14.99
#
# [2266 rows x 12 columns]

# %% [markdown]
# Si ordenamos en base a `published_date.numberLong` podemos también obtener la lista desde la publicación más antigua hasta la publicación más reciente:

# %%
df.sort_values("published_date.numberLong")
# Out:
#                                      amazon_product_url             author  \
# 0     http://www.amazon.com/The-Host-Novel-Stephenie...    Stephenie Meyer
# 1     http://www.amazon.com/Love-Youre-With-Emily-Gi...       Emily Giffin
# 2     http://www.amazon.com/The-Front-Garano-Patrici...  Patricia Cornwell
# 3     http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...    Chuck Palahniuk
# 5     http://www.amazon.com/Phantom-Prey-John-Sandfo...      John Sandford
# ...                                                 ...                ...
# 3026  http://www.amazon.com/Dont-Go-Lisa-Scottoline-...    Lisa Scottoline
# 3027  http://www.amazon.com/Unintended-Consequences-...       Stuart Woods
# 3028  http://www.amazon.com/Six-Years-Harlan-Coben/d...       Harlan Coben
# 3029  http://www.amazon.com/The-Interestings-Novel-M...       Meg Wolitzer
# 3031  http://www.amazon.com/The-Storyteller-Jodi-Pic...       Jodi Picoult
#
#                                             description            publisher  \
# 0     Descr: Aliens have taken control of the minds ...        Little, Brown
# 1     Descr: A woman's happy marriage is shaken when...         St. Martin's
# 2     Descr: A Massachusetts state investigator and ...               Putnam
# 3     Descr: An aging porn queens aims to cap her ca...            Doubleday
# 5     Descr: The Minneapolis detective Lucas Davenpo...               Putnam
# ...                                                 ...                  ...
# 3026  Descr: An Army doctor returns from Afghanistan...         St. Martin's
# 3027  Descr: The New York lawyer Stone Barrington di...               Putnam
# 3028  Descr: Jake Fisher discovers that neither the ...               Dutton
# 3029  Descr: Six friends meet in the 1970s at a summ...            Riverhead
# 3031  Descr: A New Hampshire baker finds herself in ...  Emily Bestler/Atria
#
#                          title                       oid  \
# 0                     THE HOST  5b4aa4ead3089013507db18c
# 1     LOVE THE ONE YOU'RE WITH  5b4aa4ead3089013507db18d
# 2                    THE FRONT  5b4aa4ead3089013507db18e
# 3                        SNUFF  5b4aa4ead3089013507db18f
# 5                 PHANTOM PREY  5b4aa4ead3089013507db191
# ...                        ...                       ...
# 3026                  DON'T GO  5b4aa4ead3089013507dc591
# 3027   UNINTENDED CONSEQUENCES  5b4aa4ead3089013507dc592
# 3028                 SIX YEARS  5b4aa4ead3089013507dc593
# 3029          THE INTERESTINGS  5b4aa4ead3089013507dc595
# 3031           THE STORYTELLER  5b4aa4ead3089013507dc598
#
#      bestsellers_date.numberLong  published_date.numberLong rank.numberInt  \
# 0            2008-05-24 00:00:00              1212883200000              2
# 1            2008-05-24 00:00:00              1212883200000              3
# 2            2008-05-24 00:00:00              1212883200000              4
# 3            2008-05-24 00:00:00              1212883200000              5
# 5            2008-05-24 00:00:00              1212883200000              7
# ...                          ...                        ...            ...
# 3026         2013-04-20 00:00:00              1367712000000              7
# 3027         2013-04-20 00:00:00              1367712000000              8
# 3028         2013-04-20 00:00:00              1367712000000              9
# 3029         2013-04-20 00:00:00              1367712000000             11
# 3031         2013-04-20 00:00:00              1367712000000             14
#
#       rank_last_week.numberInt  weeks_on_list.numberInt  price.numberDouble
# 0                            1                        3               25.99
# 1                            2                        2               24.95
# 2                            0                        1               22.95
# 3                            0                        1               24.95
# 5                            4                        3               26.95
# ...                        ...                      ...                 ...
# 3026                         2                        2               27.99
# 3027                         4                        2               26.95
# 3028                         8                        5               27.95
# 3029                        11                        2               27.95
# 3031                        10                        8               28.99
#
# [2266 rows x 12 columns]

# %% [markdown]
# Pero como seguramente no lo crees aún porque estamos usando la columna del Timestamp, vamos a convertir la fechas a datetime con el método:
#
# `pd.to_datetime(-dataframe[columna]-, unit="ms")`
#
# y aplicarlo desde el DataFrame original, ordenamos nuevamente y obtenemos un DataFrame sólo con las columnas `amazon_product_url` y `published_date.numberLong` para simplificar el resultado:

# %%
df["published_date.numberLong"] = pd.to_datetime(df["published_date.numberLong"], unit="ms")

df.head()
# Out:
#                                   amazon_product_url             author  \
# 0  http://www.amazon.com/The-Host-Novel-Stephenie...    Stephenie Meyer
# 1  http://www.amazon.com/Love-Youre-With-Emily-Gi...       Emily Giffin
# 2  http://www.amazon.com/The-Front-Garano-Patrici...  Patricia Cornwell
# 3  http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...    Chuck Palahniuk
# 5  http://www.amazon.com/Phantom-Prey-John-Sandfo...      John Sandford
#
#                                          description      publisher  \
# 0  Descr: Aliens have taken control of the minds ...  Little, Brown
# 1  Descr: A woman's happy marriage is shaken when...   St. Martin's
# 2  Descr: A Massachusetts state investigator and ...         Putnam
# 3  Descr: An aging porn queens aims to cap her ca...      Doubleday
# 5  Descr: The Minneapolis detective Lucas Davenpo...         Putnam
#
#                       title                       oid  \
# 0                  THE HOST  5b4aa4ead3089013507db18c
# 1  LOVE THE ONE YOU'RE WITH  5b4aa4ead3089013507db18d
# 2                 THE FRONT  5b4aa4ead3089013507db18e
# 3                     SNUFF  5b4aa4ead3089013507db18f
# 5              PHANTOM PREY  5b4aa4ead3089013507db191
#
#   bestsellers_date.numberLong published_date.numberLong rank.numberInt  \
# 0         2008-05-24 00:00:00                2008-06-08              2
# 1         2008-05-24 00:00:00                2008-06-08              3
# 2         2008-05-24 00:00:00                2008-06-08              4
# 3         2008-05-24 00:00:00                2008-06-08              5
# 5         2008-05-24 00:00:00                2008-06-08              7
#
#    rank_last_week.numberInt  weeks_on_list.numberInt  price.numberDouble
# 0                         1                        3               25.99
# 1                         2                        2               24.95
# 2                         0                        1               22.95
# 3                         0                        1               24.95
# 5                         4                        3               26.95

# %%
df_ordenado = df.sort_values("published_date.numberLong")

df_ordenado[[ "amazon_product_url","published_date.numberLong"]]
# Out:
#                                      amazon_product_url  \
# 0     http://www.amazon.com/The-Host-Novel-Stephenie...
# 1     http://www.amazon.com/Love-Youre-With-Emily-Gi...
# 2     http://www.amazon.com/The-Front-Garano-Patrici...
# 3     http://www.amazon.com/Snuff-Chuck-Palahniuk/dp...
# 5     http://www.amazon.com/Phantom-Prey-John-Sandfo...
# ...                                                 ...
# 3026  http://www.amazon.com/Dont-Go-Lisa-Scottoline-...
# 3027  http://www.amazon.com/Unintended-Consequences-...
# 3028  http://www.amazon.com/Six-Years-Harlan-Coben/d...
# 3029  http://www.amazon.com/The-Interestings-Novel-M...
# 3031  http://www.amazon.com/The-Storyteller-Jodi-Pic...
#
#      published_date.numberLong
# 0                   2008-06-08
# 1                   2008-06-08
# 2                   2008-06-08
# 3                   2008-06-08
# 5                   2008-06-08
# ...                        ...
# 3026                2013-05-05
# 3027                2013-05-05
# 3028                2013-05-05
# 3029                2013-05-05
# 3031                2013-05-05
#
# [2266 rows x 2 columns]

# %% [markdown]
# **NOTA PYTHONESCA:** Para trabajar con fechas se pueden usar los tipos de datos `datetime` o `int` (en alguna unidad de segundos), el ordenamiento u otra operación se realizará de forma correcta, pero procesar fechas de tipo `object` o `str` podríamos obtener resultados inesperados.

# %% [markdown]
# Por ejemplo, podríamos primero filtrar para sólo tener los libros de la editorial que tiene más libros como 'best sellers' usando la columna `publisher` y después ordenarlos del que pasó más días en la lista de 'best sellers' al que pasó menos días en la lista usando la columna `weeks_on_list.numberInt`.
#
# Primero encontramos la editorial con más bestsellers con el método:
#
# `dataframe[-columna-].value_counts()`

# %%
df["publisher"].value_counts()
# Out:
# Putnam                                     267
# Grand Central                              227
# Knopf                                      216
# Little, Brown                              211
# Doubleday                                  153
#                                           ...
# Morrow/HarperCollins Publishers              1
# Orbit                                        1
# Harper Voyager/HarperCollins Publishers      1
# Penguin Group (USA) Incorporated             1
# Berkeley Prime Crime                         1
# Name: publisher, Length: 69, dtype: int64

# %% [markdown]
# Filtra sólo los que perteneces a la editorial encontrada (Putnam?) usando la aplicación de filtros con:
#
# `dataframe[ dataframe[-columna-] op -valor- ]`

# %%
df_1 =  df[ df["publisher"]=="Putnam" ]
df_1.head(3)
# Out:
#                                    amazon_product_url             author  \
# 2   http://www.amazon.com/The-Front-Garano-Patrici...  Patricia Cornwell
# 5   http://www.amazon.com/Phantom-Prey-John-Sandfo...      John Sandford
# 17  http://www.amazon.com/The-Front-Garano-Patrici...  Patricia Cornwell
#
#                                           description publisher         title  \
# 2   Descr: A Massachusetts state investigator and ...    Putnam     THE FRONT
# 5   Descr: The Minneapolis detective Lucas Davenpo...    Putnam  PHANTOM PREY
# 17  Descr: A Massachusetts state investigator and ...    Putnam     THE FRONT
#
#                          oid bestsellers_date.numberLong  \
# 2   5b4aa4ead3089013507db18e         2008-05-24 00:00:00
# 5   5b4aa4ead3089013507db191         2008-05-24 00:00:00
# 17  5b4aa4ead3089013507db1a5         2008-05-31 00:00:00
#
#    published_date.numberLong rank.numberInt  rank_last_week.numberInt  \
# 2                 2008-06-08              4                         0
# 5                 2008-06-08              7                         4
# 17                2008-06-15              7                         4
#
#     weeks_on_list.numberInt  price.numberDouble
# 2                         1               22.95
# 5                         3               26.95
# 17                        2               22.95

# %% [markdown]
# Ordenando en base a la cantidad de días como bestsellers usando:
#
# `dataframe.sort_values(-columna-, ascending=False)`

# %%
df.sort_values("weeks_on_list.numberInt", ascending=False)
# Out:
#                                      amazon_product_url            author  \
# 2130  http://www.amazon.com/The-Help-Kathryn-Stocket...  Kathryn Stockett
# 2117  http://www.amazon.com/The-Help-Kathryn-Stocket...  Kathryn Stockett
# 2103  http://www.amazon.com/The-Help-Kathryn-Stocket...  Kathryn Stockett
# 2087  http://www.amazon.com/The-Help-Kathryn-Stocket...  Kathryn Stockett
# 2081  http://www.amazon.com/The-Help-Kathryn-Stocket...  Kathryn Stockett
# ...                                                 ...               ...
# 414   http://www.amazon.com/Beat-Reaper-Novel-Josh-B...       Josh Bazell
# 2257  http://www.amazon.com/The-Drop-Harry-Bosch-Nov...  Michael Connelly
# 1393  http://www.amazon.com/The-Rembrandt-Affair-Gab...      Daniel Silva
# 633   http://www.amazon.com/Road-Dogs-Novel-Elmore-L...    Elmore Leonard
# 1083  http://www.amazon.com/The-Wolf-Door-Jack-Higgi...      Jack Higgins
#
#                                             description           publisher  \
# 2130  Descr: A young white woman and two black maids...  Amy Einhorn/Putnam
# 2117  Descr: A young white woman and two black maids...  Amy Einhorn/Putnam
# 2103  Descr: A young white woman and two black maids...  Amy Einhorn/Putnam
# 2087  Descr: A young white woman and two black maids...  Amy Einhorn/Putnam
# 2081  Descr: A young white woman and two black maids...  Amy Einhorn/Putnam
# ...                                                 ...                 ...
# 414   Descr: A former hit man for the mob who has be...       Little, Brown
# 2257  Descr: Harry Bosch of the L.A.P.D. uncovers bo...       Little, Brown
# 1393  Descr: The art restorer and assassin Gabriel A...              Putnam
# 633   Descr: Cundo Rey and Jack Foley, characters fr...      William Morrow
# 1083  Descr: Someone is targeting the members of an ...              Putnam
#
#                      title                       oid  \
# 2130              THE HELP  5b4aa4ead3089013507dbf07
# 2117              THE HELP  5b4aa4ead3089013507dbeef
# 2103              THE HELP  5b4aa4ead3089013507dbeda
# 2087              THE HELP  5b4aa4ead3089013507dbec2
# 2081              THE HELP  5b4aa4ead3089013507dbeb5
# ...                    ...                       ...
# 414        BEAT THE REAPER  5b4aa4ead3089013507db440
# 2257              THE DROP  5b4aa4ead3089013507dbfeb
# 1393  THE REMBRANDT AFFAIR  5b4aa4ead3089013507dba5f
# 633              ROAD DOGS  5b4aa4ead3089013507db593
# 1083  THE WOLF AT THE DOOR  5b4aa4ead3089013507db85e
#
#      bestsellers_date.numberLong published_date.numberLong rank.numberInt  \
# 2130         2011-09-10 00:00:00                2011-09-25             13
# 2117         2011-09-03 00:00:00                2011-09-18              9
# 2103         2011-08-27 00:00:00                2011-09-11              8
# 2087         2011-08-20 00:00:00                2011-09-04              4
# 2081         2011-08-13 00:00:00                2011-08-28             11
# ...                          ...                       ...            ...
# 414          2009-01-17 00:00:00                2009-02-01             14
# 2257         2011-12-03 00:00:00                2011-12-18              1
# 1393         2010-07-25 00:00:00                2010-08-08        No Rank
# 633          2009-05-16 00:00:00                2009-05-31             13
# 1083         2010-01-24 00:00:00                2010-02-07              8
#
#       rank_last_week.numberInt  weeks_on_list.numberInt  price.numberDouble
# 2130                         9                      108               24.95
# 2117                         8                      107               24.95
# 2103                         4                      106               24.95
# 2087                        11                      105               24.95
# 2081                         0                      104               24.95
# ...                        ...                      ...                 ...
# 414                          0                        1               24.99
# 2257                         0                        1               27.99
# 1393                         0                        1               26.95
# 633                          0                        1               26.99
# 1083                         0                        1               26.95
#
# [2266 rows x 12 columns]

# %% [markdown]
# ---
# ---

# %% [markdown]
# ## Reto 6: Sort
#
# ### 1. Objetivos:
#     - Practicar el uso de `sort_values` para obtener datos específicos
#
# ### 2. Desarrollo:

# %% [markdown]
# #### a) Reordenamiento para hallazgo de valores
#
# Vamos a trabajar sobre el dataset que guardaste en la sesión anterior. Tu Reto consiste en lo siguiente:
#
# 1. Usa `sort_values` y `loc` para obtener el valor de la velocidad en kilómetros por segundo más lenta de todos los objetos que tenemos en el dataset y asígnalo a `velocidad_en_kilometros_por_segundo_de_objeto_mas_lento`.
# 2. Usa `sort_values` y `loc` para obtener el valor del diámetro más grande medido que existe en nuestro dataset y asígnalo a `medida_de_diametro_mas_grande`

# %%
df_reto_6 = pd.read_csv("objetos_cercanos_4.csv", index_col=0)
df_reto_6.head(3)
# Out:
#    Unnamed: 0.1  Unnamed: 0.1.1                     id_name  \
# 0             0               0  2154652-154652 (2004 EP20)
# 1             1               1           3153509-(2003 HM)
# 2             2               3          3837644-(2019 AY3)
#
#    is_potentially_hazardous_asteroid  \
# 0                                  0
# 1                                  1
# 2                                  0
#
#    estimated_diameter.meters.estimated_diameter_min  \
# 0                                        483.676488
# 1                                         96.506147
# 2                                         46.190746
#
#    estimated_diameter.meters.estimated_diameter_max  \
# 0                                       1081.533507
# 1                                        215.794305
# 2                                        103.285648
#
#           close_approach_date   epoch_date_close_approach orbiting_body  \
# 0  1995-01-07 00:00:00.000000  1970-01-01 00:13:09.467580         Earth
# 1  1995-01-07 00:00:00.000000  1970-01-01 00:13:09.491340         Earth
# 2  1995-01-07 00:00:00.000000  1970-01-01 00:13:09.513900         Earth
#
#    relative_velocity.kilometers_per_second  \
# 0                                16.142864
# 1                                12.351044
# 2                                22.478615
#
#    relative_velocity.kilometers_per_hour  \
# 0                           58114.308667
# 1                           44463.757734
# 2                           80923.015021
#
#                              orbit_class_description       id  \
# 0  Near Earth asteroid orbits similar to that of ...  2154652
# 1  Near Earth asteroid orbits which cross the Ear...  3153509
# 2  Near Earth asteroid orbits similar to that of ...  3837644
#
#                  name  relative_velocity.kilometers_per_minute  \
# 0  154652 (2004 EP20)                               968.571811
# 1           (2003 HM)                               741.062629
# 2          (2019 AY3)                              1348.716917
#
#    proportion_of_max_diameter_to_earth
# 0                             0.000085
# 1                             0.000017
# 2                             0.000008

# %%
df_ordenado=df_reto_6.sort_values(by="relative_velocity.kilometers_per_second", ascending=True)
#velocidad_en_kilometros_por_segundo_de_objeto_mas_lento = df_ordenado.loc[0]
velocidad_en_kilometros_por_segundo_de_objeto_mas_lento = df_ordenado.iloc[0]["relative_velocity.kilometers_per_second"]
velocidad_en_kilometros_por_segundo_de_objeto_mas_lento
# Out:
# 0.681436673

# %%
df_ordenado=df_reto_6.sort_values("estimated_diameter.meters.estimated_diameter_max", ascending=False)
#velocidad_en_kilometros_por_segundo_de_objeto_mas_lento = df_ordenado.loc[0]
medida_de_diametro_mas_grande =  df_ordenado.iloc[0]["estimated_diameter.meters.estimated_diameter_max"]
medida_de_diametro_mas_grande
# Out:
# 6516.883821679

# %% [markdown]
# En este caso la celda de valición si comprueba si tus resultados son correctos, adelante ...

# %%
def corroborar_hallazgos(velocidad_en_kilometros_por_segundo_de_objeto_mas_lento, medida_de_diametro_mas_grande):
    
    assert velocidad_en_kilometros_por_segundo_de_objeto_mas_lento == 0.681436673, 'Esa no es la velocidad en kilómetros por segundo del objeto más lento'
    assert medida_de_diametro_mas_grande == 6516.883821679, 'Ese no es el diámetro más grande medido en nuestro dataset'
    
    print('Tus hallazgos son correctos. ¡Bien hecho!')
    
corroborar_hallazgos(velocidad_en_kilometros_por_segundo_de_objeto_mas_lento, medida_de_diametro_mas_grande)
# Out:
# Tus hallazgos son correctos. ¡Bien hecho!
